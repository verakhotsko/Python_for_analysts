# %% [markdown]
# ## Задание 1.
# 1. Скачать данные по ссылке https://www.kaggle.com/datasets/ionaskel   /laptop-prices
# 2. Считать данные с помощью pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('laptop_price.csv', encoding='windows-1251', index_col='laptop_ID')
df
# Out:
#           Company                              Product            TypeName  \
# laptop_ID
# 1           Apple                          MacBook Pro           Ultrabook
# 2           Apple                          Macbook Air           Ultrabook
# 3              HP                               250 G6            Notebook
# 4           Apple                          MacBook Pro           Ultrabook
# 5           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1316       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1317       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1318       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1319           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1320         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#            Inches                            ScreenResolution  \
# laptop_ID
# 1            13.3          IPS Panel Retina Display 2560x1600
# 2            13.3                                    1440x900
# 3            15.6                           Full HD 1920x1080
# 4            15.4          IPS Panel Retina Display 2880x1800
# 5            13.3          IPS Panel Retina Display 2560x1600
# ...           ...                                         ...
# 1316         14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1317         13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1318         14.0                                    1366x768
# 1319         15.6                                    1366x768
# 1320         15.6                                    1366x768
#
#                                             Cpu   Ram               Memory  \
# laptop_ID
# 1                          Intel Core i5 2.3GHz   8GB            128GB SSD
# 2                          Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3                    Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 4                          Intel Core i7 2.7GHz  16GB            512GB SSD
# 5                          Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                         ...   ...                  ...
# 1316                 Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1317                 Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1318       Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1319                 Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1320       Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                     Gpu       OpSys  Weight  Price_euros
# laptop_ID
# 1          Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 2                Intel HD Graphics 6000       macOS  1.34kg       898.94
# 3                 Intel HD Graphics 620       No OS  1.86kg       575.00
# 4                    AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 5          Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                                 ...         ...     ...          ...
# 1316              Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1317              Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1318                  Intel HD Graphics  Windows 10   1.5kg       229.00
# 1319                 AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1320                  Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 12 columns]

# %% [markdown]
# ### 1.3. Вывести на экран первые 5 строк

# %%
df.head(5)
# Out:
#           Company      Product   TypeName  Inches  \
# laptop_ID
# 1           Apple  MacBook Pro  Ultrabook    13.3
# 2           Apple  Macbook Air  Ultrabook    13.3
# 3              HP       250 G6   Notebook    15.6
# 4           Apple  MacBook Pro  Ultrabook    15.4
# 5           Apple  MacBook Pro  Ultrabook    13.3
#
#                              ScreenResolution                         Cpu  \
# laptop_ID
# 1          IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 2                                    1440x900        Intel Core i5 1.8GHz
# 3                           Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 4          IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz
# 5          IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
#
#             Ram               Memory                           Gpu  OpSys  \
# laptop_ID
# 1           8GB            128GB SSD  Intel Iris Plus Graphics 640  macOS
# 2           8GB  128GB Flash Storage        Intel HD Graphics 6000  macOS
# 3           8GB            256GB SSD         Intel HD Graphics 620  No OS
# 4          16GB            512GB SSD            AMD Radeon Pro 455  macOS
# 5           8GB            256GB SSD  Intel Iris Plus Graphics 650  macOS
#
#            Weight  Price_euros
# laptop_ID
# 1          1.37kg      1339.69
# 2          1.34kg       898.94
# 3          1.86kg       575.00
# 4          1.83kg      2537.45
# 5          1.37kg      1803.60

# %% [markdown]
# ### 1.4. Посмотреть на описание признаков и на их содержание

# %%
df.columns                     # вывод всех признаков (столбцов)
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu',
#        'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price_euros'],
#       dtype='object')

# %%
df['Company']                  # вывод значений признака
# Out:
# laptop_ID
# 1        Apple
# 2        Apple
# 3           HP
# 4        Apple
# 5        Apple
#          ...
# 1316    Lenovo
# 1317    Lenovo
# 1318    Lenovo
# 1319        HP
# 1320      Asus
# Name: Company, Length: 1303, dtype: object

# %%
df['Product']                 # вывод значений признака
# Out:
# laptop_ID
# 1                               MacBook Pro
# 2                               Macbook Air
# 3                                    250 G6
# 4                               MacBook Pro
# 5                               MacBook Pro
#                        ...
# 1316                         Yoga 500-14ISK
# 1317                         Yoga 900-13ISK
# 1318                     IdeaPad 100S-14IBR
# 1319    15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1320    X553SA-XX031T (N3050/4GB/500GB/W10)
# Name: Product, Length: 1303, dtype: object

# %%
df.loc[5:, 'Price_euros':]    # вывод с 5 строки определенного столбца
# Out:
#            Price_euros
# laptop_ID
# 5              1803.60
# 6               400.00
# 7              2139.97
# 8              1158.70
# 9              1495.00
# ...                ...
# 1316            638.00
# 1317           1499.00
# 1318            229.00
# 1319            764.00
# 1320            369.00
#
# [1299 rows x 1 columns]

# %% [markdown]
# ## Задание 2.
# Проведите первичный анализ данных

# %% [markdown]
# ### 2.1 Изучите типы данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1303 entries, 1 to 1320
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 164.6+ KB

# %%
df.dtypes
# Out:
# Company              object
# Product              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price_euros         float64
# dtype: object

# %% [markdown]
# ### 2.2 Найдите количество пропущенных ячеек в данных

# %%
df.isna()
# Out:
#            Company  Product  TypeName  Inches  ScreenResolution    Cpu    Ram  \
# laptop_ID
# 1            False    False     False   False             False  False  False
# 2            False    False     False   False             False  False  False
# 3            False    False     False   False             False  False  False
# 4            False    False     False   False             False  False  False
# 5            False    False     False   False             False  False  False
# ...            ...      ...       ...     ...               ...    ...    ...
# 1316         False    False     False   False             False  False  False
# 1317         False    False     False   False             False  False  False
# 1318         False    False     False   False             False  False  False
# 1319         False    False     False   False             False  False  False
# 1320         False    False     False   False             False  False  False
#
#            Memory    Gpu  OpSys  Weight  Price_euros
# laptop_ID
# 1           False  False  False   False        False
# 2           False  False  False   False        False
# 3           False  False  False   False        False
# 4           False  False  False   False        False
# 5           False  False  False   False        False
# ...           ...    ...    ...     ...          ...
# 1316        False  False  False   False        False
# 1317        False  False  False   False        False
# 1318        False  False  False   False        False
# 1319        False  False  False   False        False
# 1320        False  False  False   False        False
#
# [1303 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %% [markdown]
# ### 2.3 Посчитайте основные статистики по всем признакам и поизучайте их

# %%
df.describe()         # статистика для числовых данных
# Out:
#             Inches  Price_euros
# count  1303.000000  1303.000000
# mean     15.017191  1123.686992
# std       1.426304   699.009043
# min      10.100000   174.000000
# 25%      14.000000   599.000000
# 50%      15.600000   977.000000
# 75%      15.600000  1487.880000
# max      18.400000  6099.000000

# %%
df.describe(include=[object]) # статистика для строковых данных
# Out:
#        Company Product  TypeName   ScreenResolution  \
# count     1303    1303      1303               1303
# unique      19     618         6                 40
# top       Dell  XPS 13  Notebook  Full HD 1920x1080
# freq       297      30       727                507
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1303  1303       1303                   1303
# unique                         118     9         39                    110
# top     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD  Intel HD Graphics 620
# freq                           190   619        412                    281
#
#              OpSys Weight
# count         1303   1303
# unique           9    179
# top     Windows 10  2.2kg
# freq          1072    121

# %% [markdown]
# ## Задание 3.

# %% [markdown]
# ### 3.1 Ноутбуков от какой компании больше всего в наборе данных?

# %%
df.sample(5)        # вывод случайных строк
# Out:
#              Company         Product   TypeName  Inches  \
# laptop_ID
# 1084           Apple     MacBook 12"  Ultrabook    12.0
# 1121             MSI     GE72 Apache     Gaming    17.3
# 464        Microsoft  Surface Laptop  Ultrabook    13.5
# 234               HP       ZBook 15u   Notebook    15.6
# 1027              HP   EliteBook 840  Ultrabook    14.0
#
#                              ScreenResolution                          Cpu  \
# laptop_ID
# 1084       IPS Panel Retina Display 2304x1440          Intel Core M 1.1GHz
# 1121                        Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz
# 464                     Touchscreen 2256x1504  Intel Core M m3-7Y30 2.2GHz
# 234                         Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
# 1027                        Full HD 1920x1080   Intel Core i7 6500U 2.5GHz
#
#            Ram                Memory                      Gpu         OpSys  \
# laptop_ID
# 1084       8GB   256GB Flash Storage    Intel HD Graphics 515      Mac OS X
# 1121       8GB  128GB SSD +  1TB HDD  Nvidia GeForce GTX 960M    Windows 10
# 464        4GB             128GB SSD    Intel HD Graphics 615  Windows 10 S
# 234        8GB               1TB HDD      AMD FirePro W4190M     Windows 10
# 1027       8GB             256GB SSD    Intel HD Graphics 520    Windows 10
#
#             Weight  Price_euros
# laptop_ID
# 1084       0.920kg      1300.00
# 1121         2.9kg      1511.19
# 464        1.252kg       989.00
# 234          1.9kg      1269.00
# 1027        1.54kg      1887.21

# %%
df['Company'].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
df_company = df['Company'].value_counts()
df_company[df_company == df_company.max()]
# Out:
# Dell      297
# Lenovo    297
# Name: Company, dtype: int64

# %% [markdown]
# ### 3.2 Какая минимальная и максимальная стоимость у ноутбуков в данных?

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu',
#        'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price_euros'],
#       dtype='object')

# %%
df['Price_euros'].min(), df['Price_euros'].max()
# Out:
# (174.0, 6099.0)

# %% [markdown]
# ### 3.3 Какой самый дорогой ноутбук в данных?
# Выведите все характеристики только по этому ноутбуку.
# Если таких ноутбуков несколько, то выводите их всех.

# %%
df[df['Price_euros'] == df['Price_euros'].max()]
# Out:
#           Company    Product TypeName  Inches  \
# laptop_ID
# 200         Razer  Blade Pro   Gaming    17.3
#
#                               ScreenResolution                          Cpu  \
# laptop_ID
# 200        4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz
#
#             Ram   Memory                      Gpu       OpSys  Weight  \
# laptop_ID
# 200        32GB  1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg
#
#            Price_euros
# laptop_ID
# 200             6099.0

# %% [markdown]
# ## Задание 4.

# %% [markdown]
# ### 4.1 Найдите ноутбуки с самой маленькой диагональю в данных?
# Выведите только следующие характеристики:
# 1. Компания
# 2. Типа ноутбука
# 3. Диагональ
# 4. Стоимость

# %%
df[df['Inches'] == df['Inches'].min()][['Company', 'TypeName', 'Inches', 'Price_euros']]
# Out:
#           Company            TypeName  Inches  Price_euros
# laptop_ID
# 51         Lenovo  2 in 1 Convertible    10.1       319.00
# 1097       Lenovo  2 in 1 Convertible    10.1       646.27
# 1129       Lenovo  2 in 1 Convertible    10.1       549.00
# 1141       Lenovo  2 in 1 Convertible    10.1       479.00

# %% [markdown]
# ### 4.2 Сколько стоит самый дорогой ноутбук у компании HP?

# %%
df[df['Company'] == 'HP']['Price_euros'].max()
# Out:
# 4389.0

# %% [markdown]
# ### 4.3 Как много ноутбуков Ultrabook с 8GB RAM?
# Найдите сколько таких ультрабуков с 8GB ОЗУ в процентном соотношении относительно всех ультрабуков

# %%
ultra = df[df['TypeName'] == 'Ultrabook']
ultra_8 = ultra[ultra['Ram'] == '8GB'].shape[0]
round((ultra_8 / ultra.shape[0] * 100), 2)
# Out:
# 71.43

# %%
(ultra['Ram'].value_counts(normalize=True).loc['8GB']).round(4) * 100
# Out:
# 71.43

# %% [markdown]
# ## Задание 5.

# %% [markdown]
# ### 5.1 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук с 8GB или 16GB ОЗУ на Windows 10 в стоимости до 500 евро, сколько у него вариантов?

# %%
df[(df['Ram'] == '8GB') | (df['Ram'] == '16GB')]
# Out:
#           Company               Product            TypeName  Inches  \
# laptop_ID
# 1           Apple           MacBook Pro           Ultrabook    13.3
# 2           Apple           Macbook Air           Ultrabook    13.3
# 3              HP                250 G6            Notebook    15.6
# 4           Apple           MacBook Pro           Ultrabook    15.4
# 5           Apple           MacBook Pro           Ultrabook    13.3
# ...           ...                   ...                 ...     ...
# 1303       Lenovo        Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1307         Asus  ZenBook UX305CA-UBM1           Ultrabook    13.3
# 1311       Lenovo    IdeaPad Y700-15ISK            Notebook    15.6
# 1313         Dell         Inspiron 3567            Notebook    15.6
# 1317       Lenovo        Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                      ScreenResolution  \
# laptop_ID
# 1                  IPS Panel Retina Display 2560x1600
# 2                                            1440x900
# 3                                   Full HD 1920x1080
# 4                  IPS Panel Retina Display 2880x1800
# 5                  IPS Panel Retina Display 2560x1600
# ...                                               ...
# 1303       IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1307                      IPS Panel Full HD 1920x1080
# 1311                      IPS Panel Full HD 1920x1080
# 1313                                         1366x768
# 1317       IPS Panel Quad HD+ / Touchscreen 3200x1800
#
#                                    Cpu   Ram               Memory  \
# laptop_ID
# 1                 Intel Core i5 2.3GHz   8GB            128GB SSD
# 2                 Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3           Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 4                 Intel Core i7 2.7GHz  16GB            512GB SSD
# 5                 Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                ...   ...                  ...
# 1303        Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1307          Intel Core M 6Y30 0.9GHz   8GB            512GB SSD
# 1311       Intel Core i7 6700HQ 2.6GHz   8GB              1TB HDD
# 1313        Intel Core i7 7500U 2.7GHz   8GB              1TB HDD
# 1317        Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
#
#                                     Gpu       OpSys  Weight  Price_euros
# laptop_ID
# 1          Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 2                Intel HD Graphics 6000       macOS  1.34kg       898.94
# 3                 Intel HD Graphics 620       No OS  1.86kg       575.00
# 4                    AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 5          Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                                 ...         ...     ...          ...
# 1303              Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1307              Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 1311            Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1313                 AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1317              Intel HD Graphics 520  Windows 10   1.3kg      1499.00
#
# [819 rows x 12 columns]

# %%
df[df['Ram'].isin(['8GB', '16GB']) & (df['OpSys'] == 'Windows 10') & (df['Price_euros'] < 500)].shape[0]
# Out:
# 13

# %% [markdown]
# ### 5.2 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX 1050 Ti и главное не с диагональю 15.6. В какой ценовой категории вышли подобные ноутбуки?

# %%
choice = df[(df['Company'] == 'MSI') & (df['Gpu'] == 'Nvidia GeForce GTX 1050 Ti') & (df['Inches'] != '15.6')]
choice
choice['Price_euros'].min(), choice['Price_euros'].max()
# Out:
# (1191.8, 1599.0)

# %% [markdown]
# ### 5.3 Что дешевле?
# В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel Core i7 7600U 2.8GHz?

# %%
n1 = df[df['Cpu'] == 'Intel Core i7 7700HQ 2.8GHz']['Price_euros'].mean()
n1
# Out:
# 1760.4084246575342

# %%
n2 = df[df['Cpu'] == 'Intel Core i7 7600U 2.8GHz']['Price_euros'].mean()
n2
# Out:
# 1915.710769230769

# %% [markdown]
# ## Задание 6.
# Найдите самый легкий ноутбук
# Но обратите внимание на тип и представление данных в признаке Weight, если что, замените в строке 'kg' на пустую строку через метод .str.replace()

# %%
df.sample(5)
# Out:
#           Company            Product            TypeName  Inches  \
# laptop_ID
# 856            HP    Chromebook X360  2 in 1 Convertible    11.6
# 97           Acer             Spin 5  2 in 1 Convertible    13.3
# 1086           HP        ProBook 650            Notebook    15.6
# 942          Dell        Vostro 3568            Notebook    15.6
# 1219       Lenovo  IdeaPad 310-15ISK            Notebook    15.6
#
#                                     ScreenResolution  \
# laptop_ID
# 856                             Touchscreen 1366x768
# 97         IPS Panel Full HD / Touchscreen 1920x1080
# 1086                                        1366x768
# 942                                         1366x768
# 1219                                        1366x768
#
#                                             Cpu  Ram              Memory  \
# laptop_ID
# 856        Intel Celeron Dual Core N3350 1.1GHz  4GB  32GB Flash Storage
# 97                   Intel Core i5 8250U 1.6GHz  8GB           256GB SSD
# 1086                 Intel Core i5 6200U 2.3GHz  4GB           500GB HDD
# 942                  Intel Core i5 7200U 2.5GHz  4GB             1TB HDD
# 1219                 Intel Core i7 6500U 2.5GHz  8GB           500GB HDD
#
#                               Gpu       OpSys  Weight  Price_euros
# laptop_ID
# 856         Intel HD Graphics 500   Chrome OS   1.4kg       615.00
# 97         Intel UHD Graphics 620  Windows 10   1.5kg       847.00
# 1086        Intel HD Graphics 520  Windows 10  2.31kg      1199.00
# 942         Intel HD Graphics 620  Windows 10  2.18kg       708.06
# 1219         Nvidia GeForce 920MX       No OS   2.2kg       629.00

# %%
df['Weight'] = df['Weight'].str.replace('kg', '').astype(float)
df
# Out:
#           Company                              Product            TypeName  \
# laptop_ID
# 1           Apple                          MacBook Pro           Ultrabook
# 2           Apple                          Macbook Air           Ultrabook
# 3              HP                               250 G6            Notebook
# 4           Apple                          MacBook Pro           Ultrabook
# 5           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1316       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1317       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1318       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1319           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1320         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#            Inches                            ScreenResolution  \
# laptop_ID
# 1            13.3          IPS Panel Retina Display 2560x1600
# 2            13.3                                    1440x900
# 3            15.6                           Full HD 1920x1080
# 4            15.4          IPS Panel Retina Display 2880x1800
# 5            13.3          IPS Panel Retina Display 2560x1600
# ...           ...                                         ...
# 1316         14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1317         13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1318         14.0                                    1366x768
# 1319         15.6                                    1366x768
# 1320         15.6                                    1366x768
#
#                                             Cpu   Ram               Memory  \
# laptop_ID
# 1                          Intel Core i5 2.3GHz   8GB            128GB SSD
# 2                          Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3                    Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 4                          Intel Core i7 2.7GHz  16GB            512GB SSD
# 5                          Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                         ...   ...                  ...
# 1316                 Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1317                 Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1318       Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1319                 Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1320       Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                     Gpu       OpSys  Weight  Price_euros
# laptop_ID
# 1          Intel Iris Plus Graphics 640       macOS    1.37      1339.69
# 2                Intel HD Graphics 6000       macOS    1.34       898.94
# 3                 Intel HD Graphics 620       No OS    1.86       575.00
# 4                    AMD Radeon Pro 455       macOS    1.83      2537.45
# 5          Intel Iris Plus Graphics 650       macOS    1.37      1803.60
# ...                                 ...         ...     ...          ...
# 1316              Intel HD Graphics 520  Windows 10    1.80       638.00
# 1317              Intel HD Graphics 520  Windows 10    1.30      1499.00
# 1318                  Intel HD Graphics  Windows 10    1.50       229.00
# 1319                 AMD Radeon R5 M330  Windows 10    2.19       764.00
# 1320                  Intel HD Graphics  Windows 10    2.20       369.00
#
# [1303 rows x 12 columns]

# %%
df[df['Weight'] == df['Weight'].min()]
# Out:
#           Company    Product            TypeName  Inches  \
# laptop_ID
# 51         Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 1097       Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 1129       Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 1141       Lenovo  Yoga Book  2 in 1 Convertible    10.1
#
#                           ScreenResolution                          Cpu  Ram  \
# laptop_ID
# 51         IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 1097       IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 1129       IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 1141       IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
#
#                        Memory                    Gpu       OpSys  Weight  \
# laptop_ID
# 51         64GB Flash Storage  Intel HD Graphics 400     Android    0.69
# 1097       64GB Flash Storage  Intel HD Graphics 400  Windows 10    0.69
# 1129       64GB Flash Storage  Intel HD Graphics 400     Android    0.69
# 1141       64GB Flash Storage  Intel HD Graphics 400  Windows 10    0.69
#
#            Price_euros
# laptop_ID
# 51              319.00
# 1097            646.27
# 1129            549.00
# 1141            479.00
